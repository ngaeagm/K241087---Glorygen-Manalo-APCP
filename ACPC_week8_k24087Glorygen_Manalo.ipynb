# %% [markdown]
# <a href="https://colab.research.google.com/github/ngaeagm/K241087---Glorygen-Manalo-APCP/blob/main/ACPC_week8_k24087Glorygen_Manalo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Student:
    def __init__(self, student_id, name, course):
        self.student_id = student_id
        self.name = name
        self.course = course

    def display_details(self):
        print("Student Details:")
        print("ID:", self.student_id)
        print("Name:", self.name)
        print("Course:", self.course)


# Creating an object (instance) of the Student class
student1 = Student("K241087", "Glorygen Manalo", "Bachelor of Information Technology")

# Printing the details
student1.display_details()
# Out:
# Student Details:
# ID: K241087
# Name: Glorygen Manalo
# Course: Bachelor of Information Technology
