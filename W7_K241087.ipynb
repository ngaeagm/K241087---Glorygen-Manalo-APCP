# %% [markdown]
# <a href="https://colab.research.google.com/github/ngaeagm/K241087---Glorygen-Manalo-APCP/blob/main/W7_K241087.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Creating a dictionary to store student details
student = {
    "id": "K241087",
    "name": "Glorygen Manalo",
    "course": "Bachelor of IT",
    "year": 2026
}

# Printing the dictionary
print("Student Details:")
print(student)

# Printing each detail individually
print("\nIndividual Details:")
for key in student:
    print(key, ":", student[key])
# Out:
# Student Details:
# {'id': 'K241087', 'name': 'Glorygen Manalo', 'course': 'Bachelor of IT', 'year': 2026}
#
# Individual Details:
# id : K241087
# name : Glorygen Manalo
# course : Bachelor of IT
# year : 2026
