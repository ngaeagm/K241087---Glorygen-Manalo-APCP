# %% [markdown]
# <a href="https://colab.research.google.com/github/ngaeagm/K241087---Glorygen-Manalo-APCP/blob/main/K241087_W5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time

start = time.time()

numbers = list(range(0, 101))
even_sum = sum([n for n in numbers if n % 2 == 0])

end = time.time()

print("Sum of even numbers from 0 to 100:", even_sum)
print("Execution time:", end - start, "seconds")
# Out:
# Sum of even numbers from 0 to 100: 2550
# Execution time: 0.00011396408081054688 seconds
